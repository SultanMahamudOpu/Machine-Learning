# %%
#import library
import pandas as pd

# %%
#empty df
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame

# %%
city=["Berlin","Elrngen","Zurich"]

# %%
df=pd.DataFrame(city)
df
# Out:
#          0
# 0   Berlin
# 1  Elrngen
# 2   Zurich

# %%
type(city)
# Out:
# list

# %%
row, col = df.shape

# %%
row
# Out:
# 3

# %%
col
# Out:
# 1

# %%
df.shape
# Out:
# (3, 1)

# %%
df
# Out:
#          0
# 0   Berlin
# 1  Elrngen
# 2   Zurich

# %%
df=pd.DataFrame(city, columns=["City_in_Europe"], index=["c1","c2","c3"])
df
# Out:
#    City_in_Europe
# c1         Berlin
# c2        Elrngen
# c3         Zurich

# %%
city2=["Paris","London","Madrid"]
df2=pd.DataFrame(city2, columns=["City_in_Europe"], index=["c4","c5","c6"])

# %%
df2=pd.DataFrame(zip(city,city2),columns=["city1","city2"])
df2
# Out:
#      city1   city2
# 0   Berlin   Paris
# 1  Elrngen  London
# 2   Zurich  Madrid

# %%
df2.shape
# Out:
# (3, 2)

# %%
city3=[
    ["Berlin","Elrngen","Zurich"],
    ["Paris","London","Madrid"],
    ["Rome","Milan","Naples"],
    ["Vienna","Salzburg","Innsbruck"]
    ]

# %%
city3
# Out:
# [['Berlin', 'Elrngen', 'Zurich'],
#  ['Paris', 'London', 'Madrid'],
#  ['Rome', 'Milan', 'Naples'],
#  ['Vienna', 'Salzburg', 'Innsbruck']]

# %%
df4=pd.DataFrame(city3,columns=["City1","City2","City3"], index=["c1","c2","c3","c4"])
df4
# Out:
#      City1     City2      City3
# c1  Berlin   Elrngen     Zurich
# c2   Paris    London     Madrid
# c3    Rome     Milan     Naples
# c4  Vienna  Salzburg  Innsbruck

# %%
dict1={
    "City1":["Berlin","Paris","Rome","Vienna"],
    "City2":["Elrngen","London","Milan","Salzburg"],
    "City3":["Zurich","Madrid","Naples","Innsbruck"]
    }

# %%
df5=pd.DataFrame(dict1)
df5
# Out:
#     City1     City2      City3
# 0  Berlin   Elrngen     Zurich
# 1   Paris    London     Madrid
# 2    Rome     Milan     Naples
# 3  Vienna  Salzburg  Innsbruck

# %%
type(dict1)
# Out:
# dict

# %%
#importing csv file
df6=pd.read_csv("data_set.csv")
df6
# Out:
#      student_id origin_country destination_country  destination_city  \
# 0        S00001        Finland              Russia            Moscow
# 1        S00002             UK             Germany            Aachen
# 2        S00003        Ireland              Canada         Vancouver
# 3        S00004            UAE                  UK        Birmingham
# 4        S00005   South Africa             Germany         Stuttgart
# ...         ...            ...                 ...               ...
# 4995     S04996         Canada             Germany         Stuttgart
# 4996     S04997          India             Ireland          Maynooth
# 4997     S04998             UK               India         Bangalore
# 4998     S04999        Germany              Russia  Saint Petersburg
# 4999     S05000        Finland             Germany         Stuttgart
#
#                         university_name              course_name  \
# 0     Lomonosov Moscow State University         Computer Science
# ...

# %%
#first 5 rows of the dataframe
df6.head()
# Out:
#   student_id origin_country destination_country destination_city  \
# 0     S00001        Finland              Russia           Moscow
# 1     S00002             UK             Germany           Aachen
# 2     S00003        Ireland              Canada        Vancouver
# 3     S00004            UAE                  UK       Birmingham
# 4     S00005   South Africa             Germany        Stuttgart
#
#                      university_name              course_name  \
# 0  Lomonosov Moscow State University         Computer Science
# 1                        RWTH Aachen        Civil Engineering
# 2     University of British Columbia                      Law
# 3           University of Birmingham             Data Science
# 4            University of Stuttgart  Business Administration
#
#     field_of_study  year_of_enrollment scholarship_received  \
# 0      Engineering                2021                   No
# 1              Law                2023                  Yes
# ...

# %%
#last 5 rows of the dataframe
df6.tail()
# Out:
#      student_id origin_country destination_country  destination_city  \
# 4995     S04996         Canada             Germany         Stuttgart
# 4996     S04997          India             Ireland          Maynooth
# 4997     S04998             UK               India         Bangalore
# 4998     S04999        Germany              Russia  Saint Petersburg
# 4999     S05000        Finland             Germany         Stuttgart
#
#                         university_name             course_name  \
# 4995            University of Stuttgart       Political Science
# 4996                Maynooth University       Political Science
# 4997                     IISc Bangalore                 Finance
# 4998  Saint Petersburg State University           Biotechnology
# 4999            University of Stuttgart  Mechanical Engineering
#
#         field_of_study  year_of_enrollment scholarship_received  \
# 4995       Engineering                2023                   No
# ...

# %%
#first 20 rows of the dataframe
df6.head(20)
# Out:
#    student_id origin_country destination_country destination_city  \
# 0      S00001        Finland              Russia           Moscow
# 1      S00002             UK             Germany           Aachen
# 2      S00003        Ireland              Canada        Vancouver
# 3      S00004            UAE                  UK       Birmingham
# 4      S00005   South Africa             Germany        Stuttgart
# 5      S00006            UAE        South Africa         Pretoria
# 6      S00007            UAE                  UK        Edinburgh
# 7      S00008            UAE                  UK        Cambridge
# 8      S00009          India              Russia           Moscow
# 9      S00010        Germany               India           Mumbai
# 10     S00011   South Africa                 UAE            Dubai
# 11     S00012          India                  UK        Edinburgh
# 12     S00013            UAE               India            Delhi
# ...

# %%
#last 20 rows of the dataframe
df6.tail(20)
# Out:
#      student_id origin_country destination_country  destination_city  \
# 4980     S04981          India              Canada          Montreal
# 4981     S04982            UAE              Canada          Montreal
# 4982     S04983          India                 UAE             Dubai
# 4983     S04984   South Africa                  UK            Oxford
# 4984     S04985        Finland                 USA           Chicago
# 4985     S04986             UK        South Africa         Cape Town
# 4986     S04987             UK              Canada            London
# 4987     S04988             UK                 USA       Los Angeles
# 4988     S04989            USA             Finland      Lappeenranta
# 4989     S04990         Canada             Ireland            Dublin
# 4990     S04991        Finland                  UK         Edinburgh
# 4991     S04992         Canada             Finland             Turku
# 4992     S04993            USA               India           Chennai
# ...

# %%
df6.values
# Out:
# array([['S00001', 'Finland', 'Russia', ..., 'Work Permit', 'TOEFL', 7.8],
#        ['S00002', 'UK', 'Germany', ..., 'OPT', 'PTE', 7.9],
#        ['S00003', 'Ireland', 'Canada', ..., 'Blue Card', nan, 0.0],
#        ...,
#        ['S04998', 'UK', 'India', ..., 'Post-Study Visa', 'TOEFL', 8.8],
#        ['S04999', 'Germany', 'Russia', ..., 'Blue Card', 'IELTS', 8.6],
#        ['S05000', 'Finland', 'Germany', ..., 'Work Permit', 'PTE', 5.6]],
#       shape=(5000, 20), dtype=object)

# %%
df6.columns
# Out:
# Index(['student_id', 'origin_country', 'destination_country',
#        'destination_city', 'university_name', 'course_name', 'field_of_study',
#        'year_of_enrollment', 'scholarship_received', 'enrollment_reason',
#        'graduation_year', 'placement_status', 'placement_country',
#        'placement_company', 'starting_salary_usd', 'gpa_or_score',
#        'visa_status', 'post_graduation_visa', 'language_proficiency_test',
#        'test_score'],
#       dtype='object')

# %%
df6.index
# Out:
# RangeIndex(start=0, stop=5000, step=1)

# %%
#selecting a column
df6.student_id
# Out:
# 0       S00001
# 1       S00002
# 2       S00003
# 3       S00004
# 4       S00005
#          ...
# 4995    S04996
# 4996    S04997
# 4997    S04998
# 4998    S04999
# 4999    S05000
# Name: student_id, Length: 5000, dtype: object

# %%
df6.student_id.head(15)
# Out:
# 0     S00001
# 1     S00002
# 2     S00003
# 3     S00004
# 4     S00005
# 5     S00006
# 6     S00007
# 7     S00008
# 8     S00009
# 9     S00010
# 10    S00011
# 11    S00012
# 12    S00013
# 13    S00014
# 14    S00015
# Name: student_id, dtype: object

# %%
 # multiple columns
df6[["student_id","origin_country"]].head(6)
# Out:
#   student_id origin_country
# 0     S00001        Finland
# 1     S00002             UK
# 2     S00003        Ireland
# 3     S00004            UAE
# 4     S00005   South Africa
# 5     S00006            UAE

# %%
# for sort only one column
# df6["student_id"].sort_values()
df6["student_id"].sort_values(ascending=False)
# Out:
# 4999    S05000
# 4998    S04999
# 4997    S04998
# 4996    S04997
# 4995    S04996
#          ...
# 4       S00005
# 3       S00004
# 2       S00003
# 1       S00002
# 0       S00001
# Name: student_id, Length: 5000, dtype: object

# %%
# full dataframe sorted by origin_country
df6.sort_values("origin_country")
# Out:
#      student_id origin_country destination_country destination_city  \
# 2949     S02950         Canada              Russia           Moscow
# 2577     S02578         Canada               India  Tiruchirappalli
# 526      S00527         Canada              Russia           Moscow
# 2572     S02573         Canada                 USA           Boston
# 2570     S02571         Canada             Finland            Turku
# ...         ...            ...                 ...              ...
# 3890     S03891            USA              Canada         Montreal
# 3894     S03895            USA              Russia           Moscow
# 757      S00758            USA              Canada           London
# 1480     S01481            USA              Canada        Vancouver
# 2947     S02948            USA              Russia      Novosibirsk
#
#                                  university_name             course_name  \
# 2949  Moscow Institute of Physics and Technology               Economics
# ...

# %%
# statistical Analysis (mean,count, std, min, max, 25%, 50%, 75%)
df6.describe()
# Out:
#        year_of_enrollment  graduation_year  starting_salary_usd  gpa_or_score  \
# count         5000.000000      5000.000000          5000.000000   5000.000000
# mean          2021.011000      2023.017800         44552.531000      3.246820
# std              1.420733         1.651432         50719.190623      0.430659
# min           2019.000000      2020.000000             0.000000      2.500000
# 25%           2020.000000      2022.000000             0.000000      2.877500
# 50%           2021.000000      2023.000000         30516.500000      3.240000
# 75%           2022.000000      2024.000000         87838.500000      3.610000
# max           2023.000000      2026.000000        149932.000000      4.000000
#
#         test_score
# count  5000.000000
# mean      5.632200
# std       2.973838
# min       0.000000
# 25%       5.300000
# 50%       6.500000
# 75%       7.800000
# max       9.000000

# %%
# correlation
num=df6[['year_of_enrollment','graduation_year','starting_salary_usd','gpa_or_score','test_score']]
num.corr()
# Out:
#                      year_of_enrollment  graduation_year  starting_salary_usd  \
# year_of_enrollment             1.000000         0.868798             0.005694
# graduation_year                0.868798         1.000000             0.010985
# starting_salary_usd            0.005694         0.010985             1.000000
# gpa_or_score                  -0.015113        -0.024771            -0.027943
# test_score                    -0.007475        -0.014613             0.013177
#
#                      gpa_or_score  test_score
# year_of_enrollment      -0.015113   -0.007475
# graduation_year         -0.024771   -0.014613
# starting_salary_usd     -0.027943    0.013177
# gpa_or_score             1.000000   -0.002226
# test_score              -0.002226    1.000000

# %%
import seaborn as sns
sns.heatmap(num.corr(), annot=True)
# Out:
# <Axes: >

# %%
# subseting rows
df6['year_of_enrollment'] > 2021
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 4995     True
# 4996     True
# 4997     True
# 4998    False
# 4999     True
# Name: year_of_enrollment, Length: 5000, dtype: bool

# %%
# subseting rows
df6[df6['year_of_enrollment']>2021]
# Out:
#      student_id origin_country destination_country destination_city  \
# 1        S00002             UK             Germany           Aachen
# 5        S00006            UAE        South Africa         Pretoria
# 7        S00008            UAE                  UK        Cambridge
# 9        S00010        Germany               India           Mumbai
# 10       S00011   South Africa                 UAE            Dubai
# ...         ...            ...                 ...              ...
# 4986     S04987             UK              Canada           London
# 4995     S04996         Canada             Germany        Stuttgart
# 4996     S04997          India             Ireland         Maynooth
# 4997     S04998             UK               India        Bangalore
# 4999     S05000        Finland             Germany        Stuttgart
#
#               university_name             course_name    field_of_study  \
# 1                 RWTH Aachen       Civil Engineering               Law
# ...

# %%
# subseting rows with string wiht multiple conditions
df6[(df6['origin_country']=="UK")|(df6['origin_country']=="USA")]
# Out:
#      student_id origin_country destination_country destination_city  \
# 1        S00002             UK             Germany           Aachen
# 13       S00014             UK                 USA           Boston
# 20       S00021             UK              Canada        Vancouver
# 35       S00036            USA                 UAE        Abu Dhabi
# 42       S00043            USA                 UAE            Dubai
# ...         ...            ...                 ...              ...
# 4987     S04988             UK                 USA      Los Angeles
# 4988     S04989            USA             Finland     Lappeenranta
# 4992     S04993            USA               India          Chennai
# 4993     S04994             UK        South Africa     Johannesburg
# 4997     S04998             UK               India        Bangalore
#
#                       university_name             course_name  \
# 1                         RWTH Aachen       Civil Engineering
# ...

# %%
# subseting rows with multiple conditions with isin()
df6[df6['origin_country'].isin(["UK","USA"])]
# Out:
#      student_id origin_country destination_country destination_city  \
# 1        S00002             UK             Germany           Aachen
# 13       S00014             UK                 USA           Boston
# 20       S00021             UK              Canada        Vancouver
# 35       S00036            USA                 UAE        Abu Dhabi
# 42       S00043            USA                 UAE            Dubai
# ...         ...            ...                 ...              ...
# 4987     S04988             UK                 USA      Los Angeles
# 4988     S04989            USA             Finland     Lappeenranta
# 4992     S04993            USA               India          Chennai
# 4993     S04994             UK        South Africa     Johannesburg
# 4997     S04998             UK               India        Bangalore
#
#                       university_name             course_name  \
# 1                         RWTH Aachen       Civil Engineering
# ...
